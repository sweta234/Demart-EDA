# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('DMart.csv')

# %%
df.head(5)
# Out:
#                                 Name   Brand   Price  DiscountedPrice  \
# 0             Premia Badam (Almonds)  Premia   451.0            329.0
# 1             Premia Badam (Almonds)  Premia   109.0             85.0
# 2             Premia Badam (Almonds)  Premia   202.0            175.0
# 3  Nutraj California Almonds (Badam)  Nutraj   599.0            349.0
# 4  Nutraj California Almonds (Badam)  Nutraj  1549.0            659.0
#
#   Category         SubCategory Quantity Description  \
# 0  Grocery  Grocery/Dry Fruits   500 gm       India
# 1  Grocery  Grocery/Dry Fruits   100 gm       India
# 2  Grocery  Grocery/Dry Fruits   200 gm       India
# 3  Grocery          Dry Fruits   500 gm         USA
# 4  Grocery          Dry Fruits     1 kg         USA
#
#                     BreadCrumbs
# 0  Grocery > Grocery/Dry Fruits
# 1  Grocery > Grocery/Dry Fruits
# 2  Grocery > Grocery/Dry Fruits
# 3          Grocery > Dry Fruits
# 4          Grocery > Dry Fruits

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5189 entries, 0 to 5188
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             5188 non-null   object
#  1   Brand            4789 non-null   object
#  2   Price            5188 non-null   float64
#  3   DiscountedPrice  5188 non-null   float64
#  4   Category         5186 non-null   object
#  5   SubCategory      5186 non-null   object
#  6   Quantity         5188 non-null   object
#  7   Description      5187 non-null   object
#  8   BreadCrumbs      5186 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 365.0+ KB

# %%
df.isnull().sum()
# Out:
# Name                 1
# Brand              400
# Price                1
# DiscountedPrice      1
# Category             3
# SubCategory          3
# Quantity             1
# Description          2
# BreadCrumbs          3
# dtype: int64

# %%
df.describe()
# Out:
#               Price  DiscountedPrice
# count   5188.000000      5188.000000
# mean     344.030360       236.669719
# std      601.034092       387.198716
# min        0.000000         0.000000
# 25%       85.000000        64.000000
# 50%      175.000000       125.000000
# 75%      345.000000       249.000000
# max    10990.000000      7999.000000

# %%
df['Brand'].unique()
# Out:
# array(['Premia', 'Nutraj', nan, 'Tata', 'Satyam', 'KMK',
#        'DMart Healthy Choice', 'Tata Sampann', 'Kanji Manji Kothari',
#        'ProV', 'Kalbavi', 'Kokan Gem', 'TATA', '24 Mantra Organic',
#        'Organic Tattva', 'Nutrela', '24 Mantra', 'Carnival', 'Saffola',
#        'Crown', 'Emperor', 'Falcon', 'Apis', 'King Solomon',
#        'Royal Delight', 'Shamim', 'Candor', 'Mahafruit', 'Morya',
#        'Keshar', 'Plain Jaggery', 'Laxmi', 'Miki', 'Fortune', 'Sunrich',
#        'Gemini', 'Sunday', 'Swaad', 'Dhara', 'Nature Fresh', 'Dalda',
#        'Sundrop', 'Sunny', 'Godrej', 'Aadhaar', 'Hudson', 'Svity Kolam',
#        'RiSO', 'Ricela', 'Gulab', 'Guinea', 'RRO', 'RRO Primio',
#        'Gramiyaa', 'Del Monte', 'Borges', 'Figaro', 'Leonardo',
#        'Bertolli', 'Patanjali', 'Tez', 'Idhayam', 'KLF', 'Tilsona',
#        'KPL Shudhi', 'Amul', 'Gowardhan', 'Aabad', 'Mother Dairy',
#        'Sagar', 'Prabhat', 'Chitale Dairy', 'Dynamix', 'Govind',
# ...

# %%
df['Category'].unique()
# Out:
# array(['Grocery', 'Personal Care', 'Packaged Food', 'DMart Grocery',
#        'Dairy & Beverages', 'Fruits & Vegetables', 'Home & Kitchen',
#        'Specials', 'Kitchen Aprons', 'Appliances', 'Wonderchef',
#        'Water Purifiers & Accessories', 'Tableware', 'Butterfly', nan,
#        'Joyo Plastics', 'Geep', 'Zebronics', 'Beauty & Cosmetics',
#        'Syska', 'Pigeon', 'Clothing & Accessories', 'School Supplies',
#        'Backpacks', 'Computer Accessories', 'Plant Container',
#        'Motorbike Helmets', 'Smartwatches', 'Raincoat', 'Baby & Kids'],
#       dtype=object)

# %%
df['SubCategory'].unique()
# Out:
# array(['Grocery/Dry Fruits', 'Dry Fruits', 'Dals', 'Pulses',
#        'Masala & Spices', 'Grocery/Salt / Sugar / Jaggery',
#        'Ghee & Vanaspati', 'Grocery/Rice & Rice Products',
#        'Grocery/Masala & Spices', 'Grocery/Flours & Grains',
#        'Cooking Oil', 'Hair Care', 'Gourmet Food', 'Flours & Grains',
#        'Rice & Rice Products', 'DMart Grocery/Rice & Rice Products',
#        'Pickles', 'Salt / Sugar / Jaggery', 'Snacks & Farsans',
#        'Beverages', 'DMart Grocery', 'Dairy', 'Biscuits & Cookies',
#        'Bakery', 'Personal Care', 'Ready To Cook', 'Breakfast Cereals',
#        'Packaged Food', 'Sweets', 'Ketchup & Sauce', 'Jams & Spreads',
#        'Pasta & Noodles', 'Fruits & Vegetables',
#        'Detergent & Fabric Care', 'Cleaners', 'Specials',
#        'Home & Kitchen', 'Cleaning Tools', 'Freshener & Repellents',
#        'Bed & Bath', 'Furniture & Décor', 'Disinfectants',
#        'Tissue Paper & Napkins', 'Home & Kitchen/Tissue Paper & Napkins',
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
df['Brand'].fillna('Missing', inplace=True)

# %%
df.isnull().sum()
# Out:
# Name               1
# Brand              0
# Price              1
# DiscountedPrice    1
# Category           3
# SubCategory        3
# Quantity           1
# Description        2
# BreadCrumbs        3
# dtype: int64

# %% [markdown]
# # Analiysis of the categorical data

# %%
df['Category'].value_counts()
# Out:
# Personal Care                    1234
# Packaged Food                    1125
# Home & Kitchen                    880
# Grocery                           840
# Dairy & Beverages                 429
# Specials                          187
# Clothing & Accessories             97
# Fruits & Vegetables                78
# School Supplies                    69
# Appliances                         53
# Beauty & Cosmetics                 46
# Raincoat                           33
# DMart Grocery                      31
# Plant Container                    23
# Tableware                          18
# Backpacks                          13
# Zebronics                           5
# Motorbike Helmets                   4
# Baby & Kids                         4
# Geep                                3
# Kitchen Aprons                      3
# Butterfly                           2
# Computer Accessories                2
# Joyo Plastics                       2
# Pigeon                              1
# ...

# %%
df['SubCategory'].value_counts().head(10)
# Out:
# Snacks & Farsans     302
# Beverages            282
# Skin Care            222
# Masala & Spices      204
# Hair Care            160
# Specials             157
# Bed & Bath           150
# Dairy                147
# Packaged Food        135
# Health & Wellness    129
# Name: SubCategory, dtype: int64

# %%
df['Description'].value_counts().head(1)
# Out:
# India    604
# Name: Description, dtype: int64

# %%
df['BreadCrumbs'].value_counts().head(10)
# Out:
# Packaged Food > Snacks & Farsans     291
# Dairy & Beverages > Beverages        282
# Grocery > Masala & Spices            204
# Personal Care > Skin Care            203
# Personal Care > Hair Care            160
# Specials                             157
# Dairy & Beverages > Dairy            147
# Home & Kitchen > Bed & Bath          136
# Packaged Food                        135
# Personal Care > Health & Wellness    129
# Name: BreadCrumbs, dtype: int64

# %%
df['Name'].value_counts().head(5)
# Out:
# Elle 18 Nail Pops Nail Colour - Shade 39                   7
# Trident CF Hand Towel 380 GSM - Tango Tomato - 40x60 cm    5
# Whisper Bindazzz Nights XL +                               5
# Feather Soft Black Ankle Length Legging - 1 Unit           5
# Colgate Dental Cream Strong Teeth Toothpaste               5
# Name: Name, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df['Brand'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [Name, Brand, Price, DiscountedPrice, Category, SubCategory, Quantity, Description, BreadCrumbs]
# Index: []

# %%
df['Brand'] = df['Brand'].fillna('Local/Unknown')

# %%
df.isnull().sum()
# Out:
# Name               1
# Brand              0
# Price              1
# DiscountedPrice    1
# Category           3
# SubCategory        3
# Quantity           1
# Description        2
# BreadCrumbs        3
# dtype: int64

# %%
df['DiscountPercent'] = (df['Price']-df['DiscountedPrice'])*100/df['Price']

# %%
df['DiscountPercent']
# Out:
# 0       27.050998
# 1       22.018349
# 2       13.366337
# 3       41.736227
# 4       57.456423
#           ...
# 5184    34.545455
# 5185    18.823529
# 5186    27.272727
# 5187    34.545455
# 5188    16.666667
# Name: DiscountPercent, Length: 5189, dtype: float64

# %%
df.head()
# Out:
#                                 Name   Brand   Price  DiscountedPrice  \
# 0             Premia Badam (Almonds)  Premia   451.0            329.0
# 1             Premia Badam (Almonds)  Premia   109.0             85.0
# 2             Premia Badam (Almonds)  Premia   202.0            175.0
# 3  Nutraj California Almonds (Badam)  Nutraj   599.0            349.0
# 4  Nutraj California Almonds (Badam)  Nutraj  1549.0            659.0
#
#   Category         SubCategory Quantity Description  \
# 0  Grocery  Grocery/Dry Fruits   500 gm       India
# 1  Grocery  Grocery/Dry Fruits   100 gm       India
# 2  Grocery  Grocery/Dry Fruits   200 gm       India
# 3  Grocery          Dry Fruits   500 gm         USA
# 4  Grocery          Dry Fruits     1 kg         USA
#
#                     BreadCrumbs  DiscountPercent
# 0  Grocery > Grocery/Dry Fruits        27.050998
# 1  Grocery > Grocery/Dry Fruits        22.018349
# 2  Grocery > Grocery/Dry Fruits        13.366337
# ...

# %%
df['sub_category'] = df['SubCategory'].str.split('/').str[0]

# %%
df['breadcrumbs'] = df['BreadCrumbs'].str.split('>').str[0]

# %%
df.drop('BreadCrumbs', axis = 1 , inplace = True)

# %%
df.drop('SubCategory', axis = 1 , inplace = True)

# %%
df.head()
# Out:
#                                 Name   Brand   Price  DiscountedPrice  \
# 0             Premia Badam (Almonds)  Premia   451.0            329.0
# 1             Premia Badam (Almonds)  Premia   109.0             85.0
# 2             Premia Badam (Almonds)  Premia   202.0            175.0
# 3  Nutraj California Almonds (Badam)  Nutraj   599.0            349.0
# 4  Nutraj California Almonds (Badam)  Nutraj  1549.0            659.0
#
#   Category Quantity Description  DiscountPercent sub_category breadcrumbs
# 0  Grocery   500 gm       India        27.050998      Grocery    Grocery
# 1  Grocery   100 gm       India        22.018349      Grocery    Grocery
# 2  Grocery   200 gm       India        13.366337      Grocery    Grocery
# 3  Grocery   500 gm         USA        41.736227   Dry Fruits    Grocery
# 4  Grocery     1 kg         USA        57.456423   Dry Fruits    Grocery

# %%
sns.boxplot(df['Price'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price'>

# %%
sns.boxplot(df['DiscountedPrice'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DiscountedPrice'>

# %%
df['Price'].value_counts()
# Out:
# 60.0      118
# 150.0     111
# 50.0      107
# 99.0       91
# 70.0       86
#          ...
# 605.0       1
# 1425.0      1
# 409.0       1
# 690.0       1
# 263.0       1
# Name: Price, Length: 636, dtype: int64

# %%
 df['Category'].value_counts().index
# Out:
# Index(['Personal Care', 'Packaged Food', 'Home & Kitchen', 'Grocery',
#        'Dairy & Beverages', 'Specials', 'Clothing & Accessories',
#        'Fruits & Vegetables', 'School Supplies', 'Appliances',
#        'Beauty & Cosmetics', 'Raincoat', 'DMart Grocery', 'Plant Container',
#        'Tableware', 'Backpacks', 'Zebronics', 'Motorbike Helmets',
#        'Baby & Kids', 'Geep', 'Kitchen Aprons', 'Butterfly',
#        'Computer Accessories', 'Joyo Plastics', 'Pigeon', 'Syska',
#        'Water Purifiers & Accessories', 'Wonderchef', 'Smartwatches'],
#       dtype='object')

# %%
plt.figure(figsize=(30,10))
sns.barplot(x = df['Category'].value_counts().values , y =  df['Category'].value_counts().index ,  linewidth=5 )
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(50,30))
sns.barplot(x = df['sub_category'].value_counts().values , y =  df['sub_category'].value_counts().index ,  linewidth=3 )
# Out:
# <AxesSubplot:>

# %%
 df['Price'].value_counts()
# Out:
# 60.0      118
# 150.0     111
# 50.0      107
# 99.0       91
# 70.0       86
#          ...
# 605.0       1
# 1425.0      1
# 409.0       1
# 690.0       1
# 263.0       1
# Name: Price, Length: 636, dtype: int64

# %%
 df['Quantity'].value_counts()
# Out:
# 1 U              375
# 500 gm           342
# 200 gm           292
# 100 gm           277
# 1 kg             189
#                 ...
# Nicolas Green      1
# 350 W              1
# 125 W              1
# Set Of 3           1
# 14 Shades          1
# Name: Quantity, Length: 632, dtype: int64

# %%
df['DiscountPercent'].value_counts()
# Out:
# 50.000000    328
# 20.000000    211
# 10.000000    155
# 25.000000     62
# 30.000000     52
#             ...
# 18.157895      1
# 21.846154      1
# 36.111111      1
# 14.444444      1
# 36.800000      1
# Name: DiscountPercent, Length: 1909, dtype: int64

# %%
df.groupby('Category')['DiscountPercent'].mean().sort_values(ascending=False)
# Out:
# Category
# Geep                             61.865712
# Smartwatches                     58.343057
# Butterfly                        57.467860
# Zebronics                        56.750757
# Backpacks                        51.732478
# Pigeon                           49.958275
# Wonderchef                       49.075472
# Syska                            43.804756
# Computer Accessories             37.614940
# Joyo Plastics                    36.889328
# Specials                         32.720674
# Clothing & Accessories           32.361201
# Appliances                       31.653101
# Plant Container                  30.972572
# Beauty & Cosmetics               29.153130
# Home & Kitchen                   29.010845
# Packaged Food                    28.679332
# Personal Care                    25.930840
# DMart Grocery                    24.903072
# Kitchen Aprons                   24.561404
# Fruits & Vegetables              22.323331
# ...

# %%
df['Category'].unique()
# Out:
# array(['Grocery', 'Personal Care', 'Packaged Food', 'DMart Grocery',
#        'Dairy & Beverages', 'Fruits & Vegetables', 'Home & Kitchen',
#        'Specials', 'Kitchen Aprons', 'Appliances', 'Wonderchef',
#        'Water Purifiers & Accessories', 'Tableware', 'Butterfly', nan,
#        'Joyo Plastics', 'Geep', 'Zebronics', 'Beauty & Cosmetics',
#        'Syska', 'Pigeon', 'Clothing & Accessories', 'School Supplies',
#        'Backpacks', 'Computer Accessories', 'Plant Container',
#        'Motorbike Helmets', 'Smartwatches', 'Raincoat', 'Baby & Kids'],
#       dtype=object)

# %%
  X = df[df['Category'] == 'Personal Care']

# %%
vlaues = X['Brand'].value_counts().values

# %%
Index = X['Brand'].value_counts().index

# %%
# Top 10 personal care Brand
plt.pie(vlaues[:10],labels=Index[:10],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x20f443ddd00>,
# ...
#  [Text(0.8948567564020493, 0.6397119551185545, 'Faces Canada'),
#   Text(-0.21330485128587212, 1.079120493929159, 'Insight'),
#   Text(-1.0118358323883805, 0.4314953630051119, 'Lakme'),
#   Text(-1.041952639582212, -0.3526112545958523, 'Gillette'),
#   Text(-0.7198631775869865, -0.8317433531771485, 'Nivea'),
#   Text(-0.24085045664162122, -1.073308463367136, 'Maybelline'),
#   Text(0.2682381321333857, -1.0667934685165599, 'Colgate'),
#   Text(0.6819011168723189, -0.8631401200316691, 'Lotus'),
#   Text(0.9520408691786982, -0.5510155927135536, 'Himalaya'),
#   Text(1.0836263030801319, -0.18908737470515088, 'Mamaearth')],
#  [Text(0.48810368531020865, 0.3489337937010297, '19.76%'),
#   Text(-0.11634810070138477, 0.588611178506814, '16.70%'),
#   Text(-0.5519104540300257, 0.23536110709369737, '14.26%'),
#   Text(-0.5683378034084793, -0.19233341159773762, '8.96%'),
#   Text(-0.3926526423201744, -0.453678192642081, '7.94%'),
# ...

# %%
  Y  = df[df['Category'] == 'Grocery']

# %%
Y
# Out:
#                                    Name              Brand   Price  \
# 0                Premia Badam (Almonds)             Premia   451.0
# 1                Premia Badam (Almonds)             Premia   109.0
# 2                Premia Badam (Almonds)             Premia   202.0
# 3     Nutraj California Almonds (Badam)             Nutraj   599.0
# 4     Nutraj California Almonds (Badam)             Nutraj  1549.0
# ...                                 ...                ...     ...
# 5090              Satyam Sindhav Powder             Satyam    14.0
# 5091             Tata Rock Salt Crusher               Tata   130.0
# 5128            24 Mantra Organic Sugar  24 Mantra Organic   145.0
# 5130         Organic Tattva Brown Sugar     Organic Tattva    75.0
# 5132      Organic Tattva Jaggery Powder     Organic Tattva    80.0
#
#       DiscountedPrice Category Quantity  \
# 0               329.0  Grocery   500 gm
# 1                85.0  Grocery   100 gm
# ...

# %%
V = Y['Brand'].value_counts().values

# %%
S = Y['Brand'].value_counts().index

# %%
# Top 10 grocery brand
plt.pie(V[:10],labels=S[:10],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x20f444ddbe0>,
# ...
#  [Text(0.5344789316126459, 0.9614220049812697, 'Premia'),
#   Text(-1.0534630745391564, 0.31656839795296676, 'Missing'),
#   Text(-0.6926483883328154, -0.8545397651016327, 'Satyam'),
#   Text(1.0298943251329445e-07, -1.0999999999999954, 'Everest'),
#   Text(0.39610754000373677, -1.0262060303624163, 'Fortune'),
#   Text(0.6564201874543033, -0.8826735169372975, 'Daawat'),
#   Text(0.8448291229346566, -0.7044599016561972, 'India Gate'),
#   Text(0.9723568162328897, -0.5143172386041891, 'Nutraj'),
#   Text(1.0534630875063373, -0.3165683548013214, '24 Mantra Organic'),
#   Text(1.094796470845429, -0.10686761635029596, 'Organic Tattva')],
#  [Text(0.29153396269780685, 0.5244120027170561, '33.85%'),
#   Text(-0.5746162224759035, 0.17267367161070912, '23.01%'),
#   Text(-0.3778082118178993, -0.466112599146345, '14.60%'),
#   Text(5.61760540981606e-08, -0.5999999999999974, '7.08%'),
#   Text(0.2160586581838564, -0.5597487438340452, '4.65%'),
# ...

# %%
Z = df[df['Category'] == 'Clothing & Accessories']

# %%
 d = Z['Brand'].value_counts().values

# %%
 g  = Z['Brand'].value_counts().index

# %%
# Top 10 clothing brands
plt.pie(d[:10],labels=g[:10],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x20f4bbc1220>,
# ...
#  [Text(0.808661034877338, 0.7456992226569054, 'Feather Soft'),
#   Text(-0.6494426021655336, 0.8878199741459192, 'No Fuss'),
#   Text(-1.0535990659130183, -0.3161154983660487, 'Macho'),
#   Text(-0.2645775174445169, -1.0677072338721398, 'Clio'),
#   Text(0.4978016560864326, -0.9809146299233208, 'Rupa'),
#   Text(0.8323840416100331, -0.7191222477944531, 'In Shape'),
#   Text(1.030927344910103, -0.3836519379810368, 'Dutch Harbor'),
#   Text(1.0907820994414201, -0.1421070425354356, 'I & D'),
#   Text(1.0994231228589626, -0.035620175786297614, 'Missing')],
#  [Text(0.4410878372058207, 0.40674503054013017, '23.71%'),
#   Text(-0.35424141936301834, 0.4842654404432286, '22.68%'),
#   Text(-0.5746903995889191, -0.17242663547239018, '16.49%'),
#   Text(-0.14431500951519102, -0.5823857639302581, '16.49%'),
#   Text(0.271528176047145, -0.5350443435945386, '6.19%'),
#   Text(0.454027659060018, -0.3922484987969744, '6.19%'),
# ...

# %%
df.groupby('Brand')['DiscountPercent'].mean().sort_values(ascending=False).head(20)
# Out:
# Brand
# Dr.WaterR      76.717812
# Raymond        66.698428
# Dinesmart      65.666041
# Bertolli       65.021674
# Paras          64.275466
# VIP            64.008404
# Killer         63.197026
# Aristocrat     62.837209
# Naagin         61.955556
# Dr. WaterR     61.872910
# Geep           61.865712
# Boat           61.003084
# Potronics      60.830980
# Portronics     59.237263
# Madhur         58.750000
# Ambrane        58.092118
# Trident        56.782989
# Sanjeev        56.141378
# Beezy          55.653521
# Christopher    54.347826
# Name: DiscountPercent, dtype: float64

# %%
df['Description'] = df['Description'].fillna('No Desciption')

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
text = "".join(d for d in df['Description'])

# %%
WORDCOUNT = WordCloud(width= 1600,height=800,colormap='prism',background_color = 'white').generate(text)

# %%
plt.figure(figsize = (30, 6))
plt.imshow(WORDCOUNT, interpolation="gaussian")
plt.axis("off")
plt.show()
